# %% [markdown]
# # Enunciado 3

# %%
# librerias
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# En este ejercicio realizaremos una exploración de datos en el conjunto de datos adjunto `football_goalscorers.csv`. El paquete Pandas nos sirve para trabajar más cómodamente con conjuntos de datos (datasets). Para empezar, leeremos los datos que están en formato CSV para colocarlos en una estructura de datos llamada DataFrames que facilita las operaciones.
#
# El paquete [Pandas](https://pandas.pydata.org/pandas-docs/stable/index.html) nos sirve para trabajar más cómodamente con conjuntos de datos. Para empezar, leeremos los datos que están en formato CSV para ponerlos como [DataFrames](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) de pandas, lo que facilita las operaciones.

# %%
# Cargar el fichero
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7af11f3c-3d56-4791-b528-6b42aa6a1fa1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7af11f3c-3d56-4791-b528-6b42aa6a1fa1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 1. Carga el conjunto de datos en un DataFrame de Pandas y determina el número de filas y columnas.

# %%
# TODO
df = pd.read_csv("football_goalscorers.csv")

# número de filas y columnas
filas, columnas = df.shape
print(f"El DataFrame tiene {filas} filas y {columnas} columnas.")
# Out:
# El DataFrame tiene 44362 filas y 8 columnas.

# %% [markdown]
# ### 2.Muestra las primeras 10 filas del DataFrame.

# %%
# TODO
df.head(10)
# Out:
#          date  home_team away_team       team                scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay       José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay      Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay      Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay       José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina         Alberto Ohaco     2.0
# 5  1916-07-06  Argentina     Chile      Chile        Telésforo Báez    44.0
# 6  1916-07-06  Argentina     Chile  Argentina    Juan Domingo Brown    60.0
# 7  1916-07-06  Argentina     Chile  Argentina    Juan Domingo Brown    62.0
# 8  1916-07-06  Argentina     Chile  Argentina  Alberto Marcovecchio    67.0
# 9  1916-07-06  Argentina     Chile  Argentina         Alberto Ohaco    75.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# ...

# %% [markdown]
# ### 3. Lista todos los nombres de las columnas.

# %%
# TODO
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'team', 'scorer', 'minute',
#        'own_goal', 'penalty'],
#       dtype='object')

# %% [markdown]
# ### 4.Genera una descripción estadística del DataFrame (media, máximo, mínimo, etc.).

# %%
# TODO
df.describe()
# Out:
#              minute
# count  44103.000000
# mean      50.012698
# std       26.358013
# min        1.000000
# 25%       28.000000
# 50%       51.000000
# 75%       73.000000
# max      122.000000

# %% [markdown]
# ### 5. Cambia el nombre de una columna, por ejemplo, cambia "scorer" a "nombre_jugador".

# %%
# TODO
df = df.rename(columns={"scorer": "nombre_jugador"})

# verificar los cambios
df.head()
# Out:
#          date  home_team away_team       team    nombre_jugador  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %% [markdown]
# ### 6. ¿Cuál es el equipo local (home_team) con mayor número de goles y cuántos ha marcado?

# %%
# TODO
# contar los goles locales
goles_locales = df[df["home_team"] == df["team"]].groupby("home_team").size()

# encontrar el equipo con más goles
equipo_con_mas_goles = goles_locales.idxmax()
goles_marcados = goles_locales.max()

# resultado
print(f"El equipo local con más goles es {equipo_con_mas_goles} con {goles_marcados} goles.")
# Out:
# El equipo local con más goles es Brazil con 770 goles.

# %% [markdown]
# ### 7. Haz un gráfico que muestre la distribución de goles por cada minuto.

# %%
# TODO
# asegurarse de que la columna 'minute' no tenga valores nulos y esté en formato numérico
df['minute'] = pd.to_numeric(df['minute'], errors='coerce')

# gráfico de la distribución de goles por minuto
plt.figure(figsize=(10, 6))
sns.histplot(df['minute'].dropna(), bins=range(0, 100), kde=False, color='blue')

#  títulos y etiquetas
plt.title('Distribución de Goles por Minuto', fontsize=14)
plt.xlabel('Minuto del Partido', fontsize=12)
plt.ylabel('Número de Goles', fontsize=12)

# mostrar el gráfico
plt.show()

# %% [markdown]
# # Enunciado 4
#
# En este ejercicio tendrás que importar otro archivo, en este caso el archivo con el nombre 'Melbourne_housing_FULL.csv'. Una vez cargado, se te pedirá realizar algunas visualizaciones.

# %%
# TODO

# %%
# TODO
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ad7b33a-a209-4ad0-baf7-f147dd2e5fc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ad7b33a-a209-4ad0-baf7-f147dd2e5fc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 1. Crea un diagrama de cajas (boxplot) que muestre cómo se distribuye el precio en función del número de habitaciones. Examina si el número de habitaciones influye en el precio del inmueble.

# %%
### TODO
df_housing = pd.read_csv("Melbourne_housing_FULL.csv")

#  primeras filas para entender la estructura
df_housing.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
# columnas necesarias y eliminar filas con valores nulos en 'Rooms' y 'Price'
df_housing = df_housing[['Rooms', 'Price']].dropna()

# boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rooms', y='Price', data=df_housing)

#  títulos y etiquetas
plt.title('Distribución del Precio según el Número de Habitaciones', fontsize=14)
plt.xlabel('Número de Habitaciones', fontsize=12)
plt.ylabel('Precio del Inmueble', fontsize=12)

# mostrar el gráfico
plt.show()

# %% [markdown]
# ### 2. Realiza un análisis de la relación entre el número de baños y el número de habitaciones mediante un diagrama de dispersión (scatter plot). Analiza si existe una correlación entre estos dos atributos.

# %%
# cargar el archivo CSV nuevamente
df_housing = pd.read_csv("Melbourne_housing_FULL.csv")

# todas las columnas disponibles
print(df_housing.columns)

# filtrar las columnas necesarias y eliminar filas con valores nulos
df_housing_filtered = df_housing[['Rooms', 'Bathroom']].dropna()

#  diagrama de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Rooms', y='Bathroom', data=df_housing_filtered, alpha=0.6)

# títulos y etiquetas
plt.title('Relación entre el Número de Habitaciones y el Número de Baños', fontsize=14)
plt.xlabel('Número de Habitaciones', fontsize=12)
plt.ylabel('Número de Baños', fontsize=12)

# mstrar el gráfico
plt.show()
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# calcular el coeficiente de correlación de Pearson
correlation = df_housing_filtered['Rooms'].corr(df_housing_filtered['Bathroom'])
print(f"El coeficiente de correlación entre el número de habitaciones y el número de baños es: {correlation:.2f}")
# Out:
# El coeficiente de correlación entre el número de habitaciones y el número de baños es: 0.61

# %% [markdown]
# 0.61 es bastante significativo, podría indicar que cuantas más habitaciones, más baños

# %% [markdown]
# ### 3. Agrupa los datos según el tipo de propiedad y calcula el precio promedio para cada tipo. Crea un diagrama de cajas (boxplot) para visualizar la distribución del precio según el tipo de propiedad.

# %%
### TODO

# agrupar por tipo de propiedad y calcular el precio promedio
precio_promedio = df_housing.groupby('Type')['Price'].mean().reset_index()

#  precio promedio por tipo de propiedad
print(precio_promedio)
# Out:
#   Type         Price
# 0    h  1.203718e+06
# 1    t  9.310772e+05
# 2    u  6.279434e+05

# %%
# boxplto
plt.figure(figsize=(12, 6))
sns.boxplot(x='Type', y='Price', data=df_housing)

# añadir títulos y etiquetas
plt.title('Distribución del Precio según el Tipo de Propiedad', fontsize=14)
plt.xlabel('Tipo de Propiedad', fontsize=12)
plt.ylabel('Precio del Inmueble', fontsize=12)

# mostrar el gráfico
plt.xticks(rotation=45)  # Rotar etiquetas del eje X para mejor legibilidad
plt.show()

# %% [markdown]
# ### 4. Crea un gráfico de barras con los 10 barrios que tienen el precio promedio más alto.

# %%
# TODO
# agrupar por barrio (Suburb) y calcular el precio promedio
precio_promedio_barrio = df_housing.groupby('Suburb')['Price'].mean().reset_index()

# ordenar los barrios por precio promedio de forma descendente
precio_promedio_barrio = precio_promedio_barrio.sort_values(by='Price', ascending=False)

# 10 barrios con el precio promedio más alto
top_10_barrio = precio_promedio_barrio.head(10)

# mostrar el resultado
print(top_10_barrio)
# Out:
#            Suburb         Price
# 64     Canterbury  2.386271e+06
# 220   Middle Park  2.232148e+06
# 207       Malvern  2.087619e+06
# 104      Deepdene  2.001786e+06
# 44       Brighton  1.984227e+06
# 4     Albert Park  1.927651e+06
# 22         Balwyn  1.893712e+06
# 62     Camberwell  1.861133e+06
# 188           Kew  1.796676e+06
# 23   Balwyn North  1.786109e+06

# %%
# gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x='Price', y='Suburb', data=top_10_barrio, palette='viridis')

#  títulos y etiquetas
plt.title('Los 10 Barrios con el Precio Promedio más Alto', fontsize=14)
plt.xlabel('Precio Promedio ($)', fontsize=12)
plt.ylabel('Barrio', fontsize=12)

# mostrar el gráfico
plt.show()

# %% [markdown]
# # Enunciado 5
#
# En esta sección exploraremos archivos en formato XML y JSON, y cómo realizar su exploración.

# %% [markdown]
# ### 1. Descargar el archivo XML desde una URL proporcionada. Analizar el contenido del archivo XML para extraer información sobre libros. Imprimir el contenido descargado.

# %%
import requests
import xml.etree.ElementTree as ET

# URL del fitxer XML
url = 'https://www.w3schools.com/xml/books.xml'

#
response = requests.get(url)

# le
xml_content = response.content

#
root = ET.fromstring(xml_content)

# T
for book in root.findall('book'):
    title = book.find('title').text
    author = book.find('author').text
    year = book.find('year').text
    price = book.find('price').text

    print(f"Título: {title}")
    print(f"Autor: {author}")
    print(f"Año: {year}")
    print(f"Precio: {price}")
    print("-" * 30)
# Out:
# Título: Everyday Italian
# Autor: Giada De Laurentiis
# Año: 2005
# Precio: 30.00
# ------------------------------
# Título: Harry Potter
# Autor: J K. Rowling
# Año: 2005
# Precio: 29.99
# ------------------------------
# Título: XQuery Kick Start
# Autor: James McGovern
# Año: 2003
# Precio: 49.99
# ------------------------------
# Título: Learning XML
# Autor: Erik T. Ray
# Año: 2003
# Precio: 39.95
# ------------------------------

# %% [markdown]
# ### 2. Explorar el archivo XML: Itera a través de todos los libros descargados y muestra la información que contienen.

# %%
books = []

# TODO
for book in root.findall('book'):
    book_info = {
        'Title': book.find('title').text,
        'Author': book.find('author').text,
        'Year': book.find('year').text,
        'Price': book.find('price').text
    }
    books.append(book_info)
#info de libros
for book in books:
    print(f"Título: {book['Title']}")
    print(f"Autor: {book['Author']}")
    print(f"Año: {book['Year']}")
    print(f"Precio: {book['Price']}")
    print("-" * 30)
# Out:
# Título: Everyday Italian
# Autor: Giada De Laurentiis
# Año: 2005
# Precio: 30.00
# ------------------------------
# Título: Harry Potter
# Autor: J K. Rowling
# Año: 2005
# Precio: 29.99
# ------------------------------
# Título: XQuery Kick Start
# Autor: James McGovern
# Año: 2003
# Precio: 49.99
# ------------------------------
# Título: Learning XML
# Autor: Erik T. Ray
# Año: 2003
# Precio: 39.95
# ------------------------------

# %% [markdown]
# ### 3. Convertir el archivo XML a JSON: Convierte la información extraída del archivo XML al formato JSON y guárdalo en un archivo con formato JSON.

# %%
import json

# TODO
books_json = json.dumps(books, indent=4)

# l contenido JSON en un archivo
with open('books.json', 'w') as json_file:
    json_file.write(books_json)

# mensaje de confirmación
print("Archivo 'books.json' guardado con éxito.")
# Out:
# Archivo 'books.json' guardado con éxito.

# %% [markdown]
# ### 4. Explorar el archivo JSON: Carga la información desde el archivo JSON utilizando pandas y muestra solo aquellos libros de la autora J.K Rowling.

# %%
#fFiltrar los libros de la autora "J K. Rowling" en el formato correcto
rowling_books = df_books[df_books['Author'] == 'J K. Rowling']

# mostrar los libros de J K. Rowling
print(rowling_books)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ba8f6fa1985d> in <cell line: 2>()
#       1 # Filtrar los libros de la autora "J K. Rowling" en el formato correcto
# ----> 2 rowling_books = df_books[df_books['Author'] == 'J K. Rowling']
#       3
#       4 # Mostrar los libros de J K. Rowling
#       5 print(rowling_books)
#
# NameError: name 'df_books' is not defined
